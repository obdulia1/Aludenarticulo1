# %% [markdown]
# <a href="https://colab.research.google.com/github/obdulia1/Aludenarticulo1/blob/master/00_Jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://solariabiodata.com.mx/images/solaria_banner.png" width="400">
#
# # Biodata Camp: Python
# Bienvenidos al material que hemos preparado para el Biodata Camp: Python 🐍
#
# ---

# %% [markdown]
# # 00 Biodata Camp: Python

# %% [markdown]
# ## Contenido del Curso

# %% [markdown]
# Sesion 1
#
# 	01	04 - 05pm Uso de Python, Jupyter y Spyder
#
# 	02	05 - 06pm Operaciones Aritméticas y de Texto
#
# 	03	06 - 07pm Tipos de Datos y variables
#
# 	04	07 - 08 Carga de Datos de Secuenciación y Bioinformáticos
#
#
# Sesion 2
#
# 	09 - 10 Procesamiento de Marcadores Moleculares - Rob - SARS-CoV-2
#
# 	10 - 11 Identificación de Dominios Protéicos - Luis -
#
# 			Res:
# 			- Tabla Identificando cada elemento en una sec.
# 			- PDB Modelo
#
# 	11 - 12 Visualización de Heatmaps (RNASeq, Matriz de Abundancia Tax)
#
# 			- Pandas, filtering
# 			- Numpy, transformaciones
# 			- Plotly
#
# 	12 - 13 Sesión de Preguntas
